# %% [markdown]
# <a href="https://colab.research.google.com/github/Yuvraj153973/ClassiFy/blob/main/ClassroomDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# %pip install -q "ultralytics>=8.4.0" supervision roboflow

# prevent ultralytics from tracking your activity
# !yolo settings sync=False
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.142 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 47.7/112.6 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="JJptVUk8NUDRNMUUztzb")
project = rf.workspace("yuvraj-singh-dijfm").project("student-counting-v2-cpwv7")
version = project.version(1)
dataset = version.download("yolo26")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to student-counting-v2-1 in yolo26:: 100%|██████████| 2005/2005 [00:00<00:00, 2616.38it/s]

# %%
from google.colab import drive
drive.mount('/content/drive')

from ultralytics import YOLO
model = YOLO("yolov8n.pt")

model.train(
    data="/content/student-counting-v2-1/data.yaml",
    epochs=100,
    project="/content/drive/MyDrive/yolo_runs",
    name="ClassiFy",
    save_period=1,
    patience=20
)
# Out:
# Mounted at /content/drive
# ...
# Ultralytics 8.4.142 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
